# %% [markdown]
# # Welcome to Delta -E
# <div style="width:500px; height:500px">
#
# ![section1 image](https://github.com/DeltaE/delta-e-utils/blob/e32dd3014d6ab317d3e852b03a40e5af3ef92dcf/docs/_static/logo.png?raw=true)
#
# </div>
#
# In this small example, we will learn how to use delta-e pacakage.

# %% [markdown]
# Installing development version from github repo
#
# `pip install .`
#
# Intsalling from pip
#
# `pip install delta-e`

# %%
from delta_e.utils import FileReader
import pandas as pd
from pathlib import Path

# %% [markdown]
# **One of our notable attributes is the ability to generate specialized sub-packages tailored to the specific requirements of each dataset.**
#
# An example of such a sub-package is the EPAEmissions package.
#
# https://delta-e.readthedocs.io/en/latest/api/delta_e.EPAEmissions.html

# %%
from delta_e.EPAEmissions.EPAEmissions import EpaEmissions

# %% [markdown]
# **Function to get the global warming potential adjusted emissions.**

# %%
epa = EpaEmissions()
gwp = epa.get_gwp()
gwp.loc['Natural Gas', ('co2_eq', 'kT/PJ')]
# Output: 50.3 # kT / PJ
# Out:
# 50.3458

# %% [markdown]
# **Creates emission activity ratio dataframe for OSeMOSYS Models.**

# %%
epa.get_osemosys_emissions(
        epa_fuel='Natural Gas',
        regions=['BC'],
        technologies=['GAS'],
        emissions=['co2'],
        modes=[1,2],
        years=[2020,2021])
# Out:
#   REGION TECHNOLOGY EMISSION  MODE_OF_OPERATION  YEAR  VALUE
# 0     BC        GAS      co2                  1  2020    NaN
# 1     BC        GAS      co2                  1  2021    NaN
# 2     BC        GAS      co2                  2  2020    NaN
# 3     BC        GAS      co2                  2  2021    NaN

# %% [markdown]
# **List of available fuels**

# %%
epa.get_available_fuels()
# Out:
# ['Anthracite Coal',
#  'Bituminous Coal',
#  'Sub-bituminous Coal',
#  'Lignite Coal',
#  'Mixed (Commercial Sector)',
#  'Mixed (Electric Power Sector)',
#  'Mixed (Industrial Coking)',
#  'Mixed (Industrial Sector)',
#  'Coal Coke',
#  'Municipal Solid Waste',
#  'Petroleum Coke (Solid)',
#  'Plastics',
#  'Tires',
#  'Agricultural Byproducts',
#  'Peat',
#  'Solid Byproducts',
#  'Wood and Wood Residuals',
#  'Natural Gas',
#  'Blast Furnace Gas',
#  'Coke Oven Gas',
#  'Fuel Gas',
#  'Propane Gas',
#  'Landfill Gas',
#  'Other Biomass Gases',
#  'Asphalt and Road Oil',
#  'Aviation Gasoline',
#  'Butane',
#  'Butylene',
#  'Crude Oil',
#  'Distillate Fuel Oil No. 1',
#  'Distillate Fuel Oil No. 2',
#  'Distillate Fuel Oil No. 4',
#  'Ethane',
#  'Ethylene',
#  'Heavy Gas Oils',
#  'Isobutane',
#  'Isobutylene',
#  'Kerosene',
#  'Kerosene-Type Jet Fuel',
#  'Liquefied Petroleum Gases (LPG)',
#  'Lubricants',
#  'Motor Gasoline',
#  'Naphtha (<401 deg F)',
#  'Natural Gasoline',
#  'Other Oil (>401 deg F)',
#  'Pentanes Plus',
#  'Petrochemical Feedstocks',
#  'Petroleum Coke',
#  'Propane',
#  'Propylene',
#  'Residual Fuel Oil No. 5',
#  'Residual Fuel Oil No. 6',
#  'Special Naphtha',
#  'Unfinished Oils',
#  'Used Oil',
#  'Biodiesel (100%)',
#  'Ethanol (100%)',
#  'Rendered Animal Fat',
#  'Vegetable Oil',
#  'North American Softwood',
#  'North American Hardwood',
#  'Bagasse',
#  'Bamboo',
#  'Straw']

# %% [markdown]
# ## ___Utility functions for delta_e___
#
#
# #### delta_e.utils.FileReader(filepath: str | Path)
#
# Reads in raw data.
#
#     get_data() → DataFrame
#
# Reads data to a pandas dataframe

# %%
from delta_e.utils import FileReader
import os

# Reading in the file using our inbuilt file reader
# Only supporting CSV's currently
# Local File
file_path = Path("epa_emissions.csv")
data = FileReader(file_path,isUrl=False).get_data()

# %%
# Online File
online_data = FileReader("https://oedi-data-lake.s3.amazonaws.com/ATB/electricity/csv/2023/ATBe.csv",isUrl=True).get_data()
# Out:
# c:\Users\Natsu\miniconda3\envs\delta-e\lib\site-packages\delta_e\utils.py:77: DtypeWarning: Columns (9,10,13,14,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(self.file_path)

# %%
# Since, its a panda datframe any and all functions asscociated with pandas library can be used here.
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#                        FUEL    co2_factor   ch4_factor   n2o_factor co2_gwp  \
# 0                      UNIT  kg_per_mmBtu  g_per_mmBtu  g_per_mmBtu      na
# 1           Anthracite Coal        103.69           11          1.6       1
# 2           Bituminous Coal         93.28           11          1.6       1
# 3       Sub-bituminous Coal         97.17           11          1.6       1
# 4              Lignite Coal         97.72           11          1.6       1
# ..                      ...           ...          ...          ...     ...
# 60  North American Softwood          94.4          1.9         0.42       1
# 61  North American Hardwood          93.7          1.9         0.42       1
# 62                  Bagasse          95.5          1.9         0.42       1
# 63                   Bamboo          93.7          1.9         0.42       1
# 64                    Straw          95.1          1.9         0.42       1
#
#    ch4_gwp n2o_gwp
# 0       na      na
# 1       25     298
# 2       25     298
# 3       25     298
# 4       25     298
# ..     ...     ...
# 60      25     298
# 61      25     298
# 62      25     298
# 63      25     298
# 64      25     298
#
# [65 rows x 7 columns]

# %%
online_data
# Out:
#         Unnamed: 0  atb_year     core_metric_key core_metric_parameter  \
# 0                0      2023  M100CAPEXHHNPD1A21                 CAPEX
# 1                1      2023  M100CAPEXHHNPD1A22                 CAPEX
# 2                2      2023  M100CAPEXHHNPD1A23                 CAPEX
# 3                3      2023  M100CAPEXHHNPD1A24                 CAPEX
# 4                4      2023  M100CAPEXHHNPD1A25                 CAPEX
# ...            ...       ...                 ...                   ...
# 508639      508639      2023      R75WACCRCFEM46             WACC Real
# 508640      508640      2023      R75WACCRCFEM47             WACC Real
# 508641      508641      2023      R75WACCRCFEM48             WACC Real
# 508642      508642      2023      R75WACCRCFEM49             WACC Real
# 508643      508643      2023      R75WACCRCFEM50             WACC Real
#
#        core_metric_case  crpyears  technology technology_alias techdetail  \
# 0                Market       100  Hydropower       Hydropower       NPD1
# 1                Market       100  Hydropower       Hydropower       NPD1
# 2                Market       100  Hydropower       Hydropower       NPD1
# 3                Market       100  Hydropower       Hydropower       NPD1
# 4                Market       100  Hydropower       Hydropower       NPD1
# ...                 ...       ...         ...              ...        ...
# 508639              R&D        75     Coal_FE             Coal          *
# 508640              R&D        75     Coal_FE             Coal          *
# 508641              R&D        75     Coal_FE             Coal          *
# 508642              R&D        75     Coal_FE             Coal          *
# 508643              R&D        75     Coal_FE             Coal          *
#
#        techdetail2     resourcedetail        display_name  default    scale  \
# 0            NPD 1  Hydropower - Lake  Hydropower - NPD 1        1  Utility
# 1            NPD 1  Hydropower - Lake  Hydropower - NPD 1        1  Utility
# 2            NPD 1  Hydropower - Lake  Hydropower - NPD 1        1  Utility
# 3            NPD 1  Hydropower - Lake  Hydropower - NPD 1        1  Utility
# 4            NPD 1  Hydropower - Lake  Hydropower - NPD 1        1  Utility
# ...            ...                ...                 ...      ...      ...
# 508639         NaN                NaN                   *        0      NaN
# 508640         NaN                NaN                   *        0      NaN
# 508641         NaN                NaN                   *        0      NaN
# 508642         NaN                NaN                   *        0      NaN
# 508643         NaN                NaN                   *        0      NaN
#
#        maturity  scenario  core_metric_variable units        value
# 0             Y  Advanced                  2021  $/kW  3007.709653
# 1             Y  Advanced                  2022  $/kW  3007.709653
# 2             Y  Advanced                  2023  $/kW  3007.709653
# 3             Y  Advanced                  2024  $/kW  3007.709653
# 4             Y  Advanced                  2025  $/kW  3007.709653
# ...         ...       ...                   ...   ...          ...
# 508639      NaN  Moderate                  2046   NaN     0.055780
# 508640      NaN  Moderate                  2047   NaN     0.055780
# 508641      NaN  Moderate                  2048   NaN     0.055780
# 508642      NaN  Moderate                  2049   NaN     0.055780
# 508643      NaN  Moderate                  2050   NaN     0.055780
#
# [508644 rows x 19 columns]
